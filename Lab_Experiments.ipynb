# %% [markdown]
# <a href="https://colab.research.google.com/github/pradp27/DSA0205-Computer-Vision-with-Open-CV/blob/main/Lab_Experiments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")

if img is None:
    print("Error: Image not found!")
else:

    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


    cv2_imshow(gray_img)

    cv2.imwrite("gray_image.jpg", gray_img)

    print("Image saved successfully.")
# Out:
# <PIL.Image.Image image mode=L size=736x736>
# Image saved successfully.

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread("image.jpg")

if image is None:
    print("Error: Image not found!")
else:

    blur = cv2.GaussianBlur(image, (5, 5), 10)


    cv2_imshow(blur)


    cv2.imwrite("blurred_image.jpg", blur)

    print("Blurred image saved successfully.")
# Out:
# <PIL.Image.Image image mode=RGB size=736x736>
# Blurred image saved successfully.

# %%
import cv2
from google.colab.patches import cv2_imshow

# Read the image
img = cv2.imread("image.jpg")

# Check if image is loaded
if img is None:
    print("Error: Image not found!")
else:
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect edges
    edges = cv2.Canny(gray, 100, 200)

    # Display image
    cv2_imshow(edges)

    # Save image
    cv2.imwrite("canny_edges.jpg", edges)

    print("Canny edge image saved successfully.")
# Out:
# <PIL.Image.Image image mode=L size=736x736>
# Canny edge image saved successfully.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Read image in grayscale
img = cv2.imread("image.jpg", cv2.IMREAD_GRAYSCALE)

# Check if image is loaded
if img is None:
    print("Error: Image not found!")
else:
    # Create kernel
    kernel = np.ones((5, 5), np.uint8)

    # Apply dilation
    dilated_img = cv2.dilate(img, kernel, iterations=1)

    # Display image
    cv2_imshow(dilated_img)

    # Save image
    cv2.imwrite("dilated_image.jpg", dilated_img)

    print("Dilated image saved successfully.")
# Out:
# <PIL.Image.Image image mode=L size=736x736>
# Dilated image saved successfully.

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Read image
img = cv2.imread("image.jpg")

# Check if image is loaded
if img is None:
    print("Error: Image not found!")
else:
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Create kernel
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))

    # Apply erosion
    eroded_img = cv2.erode(gray, kernel, iterations=1)

    # Display image
    cv2_imshow(eroded_img)

    # Save image
    cv2.imwrite("eroded_image.jpg", eroded_img)

    print("Eroded image saved successfully.")
# Out:
# <PIL.Image.Image image mode=L size=736x736>
# Eroded image saved successfully.

# %%
import cv2
from google.colab.patches import cv2_imshow

cap = cv2.VideoCapture("video.mp4")

count = 0

if not cap.isOpened():
    print("Error: Cannot open video.")
else:
    while count < 2:
        ret, frame = cap.read()

        if not ret:
            break

        slow_frame = cv2.resize(frame, None, fx=0.5, fy=0.5)
        fast_frame = cv2.resize(frame, None, fx=2.0, fy=2.0)

        print(f"Frame {count + 1} - Slow Motion")
        cv2_imshow(slow_frame)

        print(f"Frame {count + 1} - Fast Motion")
        cv2_imshow(fast_frame)

        input("Press Enter for next frame...")

        count += 1

cap.release()
print("Video processing completed.")
# Out:
# Frame 1 - Slow Motion
# <PIL.Image.Image image mode=RGB size=320x152>
# Frame 1 - Fast Motion
# <PIL.Image.Image image mode=RGB size=1280x608>
# Press Enter for next frame...
# Frame 2 - Slow Motion
# <PIL.Image.Image image mode=RGB size=320x152>
# Frame 2 - Fast Motion
# <PIL.Image.Image image mode=RGB size=1280x608>
# Press Enter for next frame...
# Video processing completed.
